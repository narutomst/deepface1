# %%
from deepface import DeepFace
import cv2
# import maplotl

# %%
img_path = 'demo1.jpg'
img = cv2.imread(img_path)
# cv2.imshow('img',img)
# key = cv2.waitKey(0)
# if key == ord('q'):
#     break
# cv2.destroyAllWindows()

# %%
import os
from pathlib import Path
str(os.getenv("DEEPFACE_HOME", default=str(Path.home())))
# Out:
# 'C:\\Users\\Administrator'

# %%
result = DeepFace.verify('img1.jpg', 'img2.jpg')

result
# Out:
# {'verified': True,
#  'distance': 0.018277737794679894,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 585, 'y': 906, 'w': 805, 'h': 805},
#   'img2': {'x': 556, 'y': 808, 'w': 864, 'h': 864}},
#  'time': 1.02}

# %%
dfs = DeepFace.find(img_path = "img1.jpg", db_path = "C:/workspace/my_db")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2188\1666138554.py in <module>
# ----> 1 dfs = DeepFace.find(img_path = "img1.jpg", db_path = "C:/workspace/my_db")
#
# h:\AAAWorkRecord\2024年4月\20240415\EmotionRecognition\deepface\deepface\DeepFace.py in find(img_path, db_path, model_name, distance_metric, enforce_detection, detector_backend, align, normalization, silent)
#     447     # -------------------------------
#     448     if os.path.isdir(db_path) is not True:
# --> 449         raise ValueError("Passed db_path does not exist!")
#     450
#     451     target_size = functions.find_target_size(model_name=model_name)
#
# ValueError: Passed db_path does not exist!

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.3626399420276012,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 585, 'y': 906, 'w': 805, 'h': 805},
#   'img2': {'x': 86, 'y': 113, 'w': 227, 'h': 227}},
#  'time': 0.59}

# %%
demography = DeepFace.analyze(img_path,actions=["emotion", "age", "gender", "race"])
demography
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00, 10.45it/s]
# [{'emotion': {'angry': 6.290953001586441e-11,
#    'disgust': 2.4232471861307396e-22,
#    'fear': 3.5131043039926535e-10,
#    'happy': 99.80071187019348,
#    'sad': 1.4870923936705083e-08,
#    'surprise': 0.1941263908520341,
#    'neutral': 0.005163597597857006},
#   'dominant_emotion': 'happy',
#   'region': {'x': 89, 'y': 35, 'w': 99, 'h': 99},
#   'age': 29,
#   'gender': {'Woman': 81.6522479057312, 'Man': 18.347755074501038},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 99.92716908454895,
#    'indian': 0.0159639137564227,
#    'black': 2.818335644860781e-05,
#    'white': 0.012707991118077189,
#    'middle eastern': 0.00018701887256611371,
#    'latino hispanic': 0.04394548013806343},
#   'dominant_race': 'asian'}]

# %%
emotion = demography[0]['dominant_emotion']
region = (demography[0]['region']['x'], demography[0]['region']['y'], demography[0]['region']['w'], demography[0]['region']['h'])
age = demography[0]['age']
gender = demography[0]['dominant_gender']
race = demography[0]['dominant_race']
print("emotion:",emotion)
print("region:",region)
print("age:",age)
print("gender:",gender)
print("race:",race)
# Out:
# emotion: happy
# region: (89, 35, 99, 99)
# age: 29
# gender: Woman
# race: asian

# %%
demography = DeepFace.analyze('img3.jpg',actions=["emotion", "age", "gender", "race"])
emotion = demography[0]['dominant_emotion']
rate = demography[0]['emotion'][emotion]
region = (demography[0]['region']['x'], demography[0]['region']['y'], demography[0]['region']['w'], demography[0]['region']['h'])
age = demography[0]['age']
gender = demography[0]['dominant_gender']
race = demography[0]['dominant_race']
print("emotion:",emotion)
print("Rate:",rate)
print("region:",region)
print("age:",age)
print("gender:",gender)
print("race:",race)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  9.85it/s]
# emotion: neutral
# Rate: 96.97039127349854
# region: (86, 113, 227, 227)
# age: 30
# gender: Man
# race: asian

# %%
demography[0]['emotion']
# Out:
# {'angry': 0.4412491340190172,
#  'disgust': 3.8704766325281525e-05,
#  'fear': 7.467138767242432,
#  'happy': 0.1163757755421102,
#  'sad': 87.97441720962524,
#  'surprise': 0.02339931234018877,
#  'neutral': 3.97738516330719}

# %%
dfs = DeepFace.find('img2.jpg',"my_db")
# Out:
# Finding representations: 100%|██████████| 3/3 [00:00<00:00,  4.20it/s]
# Representations stored in my_db/representations_vgg_face.pkl file.Please delete this file when you add new identities in your database.
# find function lasts  1.282655954360962  seconds

# %%
data = dfs[0]
data
# Out:
#         identity  source_x  source_y  source_w  source_h  VGG-Face_cosine
# 0  my_db/桂永雷.jpg       556       808       864       864         0.018278
# 1  my_db/杨文峰.jpg       556       808       864       864         0.357538

# %%
data['VGG-Face_cosine']
# Out:
# 0    0.018278
# 1    0.357538
# Name: VGG-Face_cosine, dtype: float64

# %%
import pandas as pd
index = data['VGG-Face_cosine'].idxmin()
identity = data['identity'][index].split('.')[0].split('/')[1]
identity
# Out:
# '桂永雷'

# %%
e2z = {'angry': '生气',
 'disgust': '厌恶',
 'fear': '害怕',
 'happy': '高兴',
 'sad': '悲伤',
 'surprise': '惊讶',
 'neutral': '正常'}

# %%
# 视频视差图


# import maplotl

from __future__ import print_function
import numpy as np
import cv2
from PIL import Image,ImageDraw,ImageFont
from deepface import DeepFace
def get_video_info(video_cap):

    width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    numFrames = int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    return width, height, numFrames, fps
def cv2AddChineseText(img, text, position, textColor=(0, 255, 0), textSize=30):
    if (isinstance(img, np.ndarray)):  # 判断是否OpenCV图片类型
        img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    # 创建一个可以在给定图像上绘图的对象
    draw = ImageDraw.Draw(img)
    # 字体的格式
    fontStyle = ImageFont.truetype(
        "simsun.ttc", textSize, encoding="utf-8")
    # 绘制文本
    draw.text(position, text, textColor, font=fontStyle)
    # 转换回OpenCV格式
    return cv2.cvtColor(np.asarray(img), cv2.COLOR_RGB2BGR)

#q ----- 本地读图
# imgL = cv2.imread("data/camera/left_000.png",1)
# imgL = cv2.resize(imgL,(640,480))

# imgR = cv2.imread("data/camera/right_000.png",1)
# imgR = cv2.resize(imgR,(640,480))
# ----- 单线双目摄像头读图
cap = cv2.VideoCapture(0)
# cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640 * 2)
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# width, height, numFrames, fps = get_video_info(cap)
# print("capL:\n", width, height, numFrames, fps)

while True:
    isuccess, frame = cap.read()
    if not isuccess:
        print("No more frames")
        break
    # 分离左右摄像头
    # imgL = frame[:, :int(width / 2), :]
    img = frame
    try:
        
        # imgR = frame[:, int(width / 2):, :]
        # demography = DeepFace.analyze(imgL,actions='emotion')
        demography = DeepFace.analyze(img,actions=["emotion", "age", "gender", "race"])
        emotion = demography[0]['dominant_emotion']
        rate = demography[0]['emotion'][emotion]
        # region = (demography[0]['region']['x'], demography[0]['region']['y'], demography[0]['region']['w'], demography[0]['region']['h'])
        region = demography[0]['region']
        age = demography[0]['age']
        gender = demography[0]['dominant_gender']
        race = demography[0]['dominant_race']
        # print(res)
        
        img = cv2.rectangle(img,(region['x'],region['y']),(region['x']+region['w'],region['y']+region['h']),(0,255,0),2)

        # imgL = cv2AddChineseText(imgL, '{} {:.3f}'.format(e2z[res],rate), (region['x'], region['y']-60), textColor=(0, 255, 0), textSize=60)
        img = cv2AddChineseText(img, '{}-{}-{}-{}'.format(emotion,age,gender,race), (region['x'], region['y']-60), textColor=(0, 255, 0), textSize=60)
        # font=cv2.FONT_HERSHEY_SIMPLEX  # 定义字体

        # imgL = cv2.putText(imgL, '{} {:.3f}'.format(e2z[res],b), (region['x'], region['y']-10), font, 0.5, (0, 255, 0), 1)

        # Calculating disparith using the StereoSGBM algorithm
        # 计算视差
    except ValueError:
        print('Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.')
        img = frame
        # Displaying the disparity map
        # 显示结果
    cv2.imshow("left image",img)
    # cv2.imshow("right image",imgR)
    key = cv2.waitKey(10)
    if key == ord('q'):
        break
    
cv2.destroyAllWindows()
# Out:
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# ...
