# %%
from deepface import DeepFace
import cv2
# import maplotl
import pandas as pd

# %%
data = DeepFace.find('img2.jpg',"my_db")[0]
data
# Out:
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.5276856422424316  seconds
#         identity  source_x  source_y  source_w  source_h  VGG-Face_cosine
# 0  my_db/桂永雷.jpg       556       808       864       864         0.018278
# 1  my_db/杨文峰.jpg       556       808       864       864         0.357538

# %%
index = data['VGG-Face_cosine'].idxmin()
identity = data['identity'][index].split('.')[0].split('/')[1]
region = {'x':data['source_x'][index],
          'y':data['source_y'][index],
          'w':data['source_w'][index],
          'h':data['source_h'][index]}

identity,region
# Out:
# ('桂永雷', {'x': 556, 'y': 808, 'w': 864, 'h': 864})

# %%
# 视频视差图
from __future__ import print_function

from deepface import DeepFace
import cv2
import pandas as pd

import numpy as np
import cv2
from PIL import Image,ImageDraw,ImageFont
def get_video_info(video_cap):

    width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    numFrames = int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    return width, height, numFrames, fps
def cv2AddChineseText(img, text, position, textColor=(0, 255, 0), textSize=30):
    if (isinstance(img, np.ndarray)):  # 判断是否OpenCV图片类型
        img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    # 创建一个可以在给定图像上绘图的对象
    draw = ImageDraw.Draw(img)
    # 字体的格式
    fontStyle = ImageFont.truetype(
        "simsun.ttc", textSize, encoding="utf-8")
    # 绘制文本
    draw.text(position, text, textColor, font=fontStyle)
    # 转换回OpenCV格式
    return cv2.cvtColor(np.asarray(img), cv2.COLOR_RGB2BGR)


cap = cv2.VideoCapture(0)


while True:
    isuccess, frame = cap.read()
    if not isuccess:
        print("No more frames")
        break
    # 分离左右摄像头
    # imgL = frame[:, :int(width / 2), :]
    img = frame
    try:
        
        data = DeepFace.find(img,"my_db")[0]
        index = data['VGG-Face_cosine'].idxmin()
        identity = data['identity'][index].split('.')[0].split('/')[1]
        region = {'x':data['source_x'][index],
                'y':data['source_y'][index],
                'w':data['source_w'][index],
                'h':data['source_h'][index]}
        
        img = cv2.rectangle(img,(region['x'],region['y']),(region['x']+region['w'],region['y']+region['h']),(0,255,0),2)

        # imgL = cv2AddChineseText(imgL, '{} {:.3f}'.format(e2z[res],rate), (region['x'], region['y']-60), textColor=(0, 255, 0), textSize=60)
        img = cv2AddChineseText(img, '{}'.format(identity), (region['x'], region['y']-60), textColor=(0, 255, 0), textSize=60)
        # font=cv2.FONT_HERSHEY_SIMPLEX  # 定义字体

        # imgL = cv2.putText(imgL, '{} {:.3f}'.format(e2z[res],b), (region['x'], region['y']-10), font, 0.5, (0, 255, 0), 1)

        # Calculating disparith using the StereoSGBM algorithm
        # 计算视差
    except ValueError:
        print('Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.')
        img = frame
        # Displaying the disparity map
        # 显示结果
    cv2.imshow("left image",img)
    # cv2.imshow("right image",imgR)
    key = cv2.waitKey(10)
    if key == ord('q'):
        break
    
cv2.destroyAllWindows()
# Out:
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.15368342399597168  seconds
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.16079473495483398  seconds
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.1481177806854248  seconds
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.1549997329711914  seconds
# Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# WARNING: Representations for images in my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  0.1553027629852295  seconds
